# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/corazzon/finance-data-analysis/blob/main/4.1%20ETF%20%EB%AA%A9%EB%A1%9D%20%EC%88%98%EC%A7%91-input.ipynb)
#
#
# ## ETF란?
# * ETF(상장지수펀드)는 기초지수의 성과를 추적하는 것이 목표인 인덱스펀드로, 거래소에 상장되어 있어서 개별주식과 마찬가지로 기존의 주식계좌를 통해 거래를 할 수 있습니다. 그 구성종목과 수량 등 자산구성내역(PDF)이 투명하게 공개되어 있고, 장중에는 실시간으로 순자산가치(NAV)가 제공되어 거래에 참고하실 수 있습니다. ETF는 1좌를 거래할 수 있는 최소한의 금액만으로 분산투자 효과를 누릴 수 있어 효율적인 투자수단이며, 펀드보다 운용보수가 낮고 주식에 적용되는 거래세도 붙지 않습니다.
#     * 출처 : [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)
#
#
# ## 크롬 브라우저의 네트워크 정보를 통한 데이터 수집
# * json 데이터 수집과 파일저장 방법
#
# * [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)

# %%
# 라이브러리를 불러옵니다.
# 데이터 분석을 위한 pandas, 수치계산을 위한 numpy, http 요청을 위한 requests를 받아옵니다.
import pandas as pd
import numpy as np
import requests

# %%
# 수집할 url을 가져옵니다.
url = 'https://finance.naver.com/api/sise/etfItemList.nhn'
url
# Out:
# 'https://finance.naver.com/api/sise/etfItemList.nhn'

# %% [markdown]
# ## Pandas를 통한 요청

# %%
# pd.read_html(url)

# %% [markdown]
# ## JSON
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/JSON_vector_logo.svg/300px-JSON_vector_logo.svg.png" width="100">
#
# JSON(제이슨, JavaScript Object Notation)은 속성-값 쌍( attribute–value pairs and array data types (or any other serializable value)) 또는 "키-값 쌍"으로 이루어진 데이터 오브젝트를 전달하기 위해 인간이 읽을 수 있는 텍스트를 사용하는 개방형 표준 포맷이다. 비동기 브라우저/서버 통신 (AJAX)을 위해, 넓게는 XML(AJAX가 사용)을 대체하는 주요 데이터 포맷이다. 특히, 인터넷에서 자료를 주고 받을 때 그 자료를 표현하는 방법으로 알려져 있다. 자료의 종류에 큰 제한은 없으며, 특히 컴퓨터 프로그램의 변수값을 표현하는 데 적합하다.
# 본래는 자바스크립트 언어로부터 파생되어 자바스크립트의 구문 형식을 따르지만 언어 독립형 데이터 포맷이다. 즉, 프로그래밍 언어나 플랫폼에 독립적이므로, 구문 분석 및 JSON 데이터 생성을 위한 코드는 C, C++, C#, 자바, 자바스크립트, 펄, 파이썬 등 수많은 프로그래밍 언어에서 쉽게 이용할 수 있다.
#
# * 출처 : [JSON - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/JSON)

# %% [markdown]
# ## requests를 통한 HTTP 요청
# * [Requests: HTTP for Humans™ — Requests documentation](https://requests.readthedocs.io/en/master/)

# %%
# requests 라이브러리를 통해 url을 받아옵니다.
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'resultCode': 'success',
#  'result': {'etfItemList': [{'itemcode': '069500',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200',
#     'nowVal': 43005,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 0.3,
#     'nav': 43027.0,
#     'threeMonthEarnRate': -0.7363,
#     'quant': 2409683,
#     'amonut': 103245,
#     'marketSum': 41672},
#    {'itemcode': '153130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권',
#     'nowVal': 102845,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 102846.0,
#     'threeMonthEarnRate': 0.034,
#     'quant': 16993,
#     'amonut': 1747,
#     'marketSum': 24206},
#    {'itemcode': '252670',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 200선물인버스2X',
#     'nowVal': 1930,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.52,
#     'nav': 1930.0,
#     'threeMonthEarnRate': 0.0,
#     'quant': 208297922,
#     'amonut': 404216,
#     'marketSum': 22070},
#    {'itemcode': '102110',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 200',
#     'nowVal': 43020,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.2,
#     'nav': 43060.0,
#     'threeMonthEarnRate': -0.7054,
#     'quant': 917304,
#     'amonut': 39354,
#     'marketSum': 21575},
#    {'itemcode': '102780',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 삼성그룹',
#     'nowVal': 10570,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.33,
#     'nav': 10594.0,
#     'threeMonthEarnRate': 3.2033,
#     'quant': 254361,
#     'amonut': 2680,
#     'marketSum': 18180},
#    {'itemcode': '214980',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권PLUS',
#     'nowVal': 103150,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.01,
#     'nav': 103151.0,
#     'threeMonthEarnRate': 0.0581,
#     'quant': 869568,
#     'amonut': 89698,
#     'marketSum': 14314},
#    {'itemcode': '122630',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 레버리지',
#     'nowVal': 27990,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 0.45,
#     'nav': 28203.0,
#     'threeMonthEarnRate': -2.2281,
#     'quant': 13294924,
#     'amonut': 369660,
#     'marketSum': 13995},
#    {'itemcode': '273130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 종합채권(AA-이상)액티브',
#     'nowVal': 109845,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.04,
#     'nav': 109832.0,
#     'threeMonthEarnRate': 0.8356,
#     'quant': 5949,
#     'amonut': 653,
#     'marketSum': 13935},
#    {'itemcode': '278530',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200TR',
#     'nowVal': 14065,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.36,
#     'nav': 14072.0,
#     'threeMonthEarnRate': -0.849,
#     'quant': 24819,
#     'amonut': 347,
#     'marketSum': 12743},
#    {'itemcode': '292150',
#     'etfTabCode': 2,
#     'itemname': 'TIGER TOP10',
#     'nowVal': 14750,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.44,
#     'nav': 14793.0,
#     'threeMonthEarnRate': 0.4542,
#     'quant': 291659,
#     'amonut': 4297,
#     'marketSum': 12692},
#    {'itemcode': '371460',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나전기차SOLACTIVE',
#     'nowVal': 15635,
#     'risefall': '5',
#     'changeVal': -365,
#     'changeRate': -2.28,
#     'nav': None,
#     'threeMonthEarnRate': 48.0795,
#     'quant': 9662619,
#     'amonut': 150205,
#     'marketSum': 11833},
#    {'itemcode': '278540',
#     'etfTabCode': 1,
#     'itemname': 'KODEX MSCI Korea TR',
#     'nowVal': 13735,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.04,
#     'nav': 13771.0,
#     'threeMonthEarnRate': -1.7168,
#     'quant': 264815,
#     'amonut': 3627,
#     'marketSum': 11469},
#    {'itemcode': '148020',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200',
#     'nowVal': 43080,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 0.3,
#     'nav': 43100.0,
#     'threeMonthEarnRate': -0.6776,
#     'quant': 30555,
#     'amonut': 1311,
#     'marketSum': 10705},
#    {'itemcode': '157450',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기통안채',
#     'nowVal': 100240,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100240.0,
#     'threeMonthEarnRate': 0.0648,
#     'quant': 1446,
#     'amonut': 144,
#     'marketSum': 10689},
#    {'itemcode': '114800',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 인버스',
#     'nowVal': 3765,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.13,
#     'nav': 3765.0,
#     'threeMonthEarnRate': 0.1328,
#     'quant': 32299879,
#     'amonut': 121963,
#     'marketSum': 10659},
#    {'itemcode': '139260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 IT',
#     'nowVal': 38510,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.22,
#     'nav': 38559.0,
#     'threeMonthEarnRate': -4.0976,
#     'quant': 171594,
#     'amonut': 6587,
#     'marketSum': 9250},
#    {'itemcode': '305720',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지산업',
#     'nowVal': 20800,
#     'risefall': '5',
#     'changeVal': -150,
#     'changeRate': -0.72,
#     'nav': 20850.0,
#     'threeMonthEarnRate': 6.1619,
#     'quant': 1731884,
#     'amonut': 36073,
#     'marketSum': 9027},
#    {'itemcode': '152100',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200',
#     'nowVal': 43410,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 0.28,
#     'nav': 43448.0,
#     'threeMonthEarnRate': -0.7384,
#     'quant': 77205,
#     'amonut': 3338,
#     'marketSum': 8942},
#    {'itemcode': '233740',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥150 레버리지',
#     'nowVal': 15430,
#     'risefall': '5',
#     'changeVal': -435,
#     'changeRate': -2.74,
#     'nav': 15584.0,
#     'threeMonthEarnRate': 1.2444,
#     'quant': 9591156,
#     'amonut': 149120,
#     'marketSum': 8749},
#    {'itemcode': '133690',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥100',
#     'nowVal': 77430,
#     'risefall': '5',
#     'changeVal': -510,
#     'changeRate': -0.65,
#     'nav': None,
#     'threeMonthEarnRate': 11.6139,
#     'quant': 95659,
#     'amonut': 7403,
#     'marketSum': 8595},
#    {'itemcode': '364980',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX2차전지K-뉴딜',
#     'nowVal': 17525,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.06,
#     'nav': 17533.0,
#     'threeMonthEarnRate': 2.4539,
#     'quant': 777062,
#     'amonut': 13616,
#     'marketSum': 7527},
#    {'itemcode': '105190',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 200',
#     'nowVal': 43095,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 0.27,
#     'nav': 43115.0,
#     'threeMonthEarnRate': -0.7505,
#     'quant': 227483,
#     'amonut': 9774,
#     'marketSum': 7326},
#    {'itemcode': '310970',
#     'etfTabCode': 1,
#     'itemname': 'TIGER MSCI Korea TR',
#     'nowVal': 17300,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.12,
#     'nav': 17299.0,
#     'threeMonthEarnRate': -1.6506,
#     'quant': 2164,
#     'amonut': 37,
#     'marketSum': 7180},
#    {'itemcode': '305540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지테마',
#     'nowVal': 20085,
#     'risefall': '5',
#     'changeVal': -200,
#     'changeRate': -0.99,
#     'nav': 20082.0,
#     'threeMonthEarnRate': 9.0884,
#     'quant': 1398973,
#     'amonut': 28081,
#     'marketSum': 7060},
#    {'itemcode': '091180',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 자동차',
#     'nowVal': 23230,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -0.54,
#     'nav': 23232.0,
#     'threeMonthEarnRate': 2.3354,
#     'quant': 290735,
#     'amonut': 6747,
#     'marketSum': 6435},
#    {'itemcode': '293180',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200',
#     'nowVal': 43015,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.23,
#     'nav': 43049.0,
#     'threeMonthEarnRate': -0.7126,
#     'quant': 86127,
#     'amonut': 3693,
#     'marketSum': 6194},
#    {'itemcode': '069660',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200',
#     'nowVal': 43015,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 0.27,
#     'nav': 43030.0,
#     'threeMonthEarnRate': -0.7198,
#     'quant': 3762,
#     'amonut': 161,
#     'marketSum': 6087},
#    {'itemcode': '314250',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국FANG플러스(H)',
#     'nowVal': 28230,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.04,
#     'nav': None,
#     'threeMonthEarnRate': 2.4505,
#     'quant': 464589,
#     'amonut': 12994,
#     'marketSum': 5561},
#    {'itemcode': '315930',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Top5PlusTR',
#     'nowVal': 19650,
#     'risefall': '5',
#     'changeVal': -80,
#     'changeRate': -0.41,
#     'nav': 19653.0,
#     'threeMonthEarnRate': -1.6206,
#     'quant': 6846,
#     'amonut': 133,
#     'marketSum': 5089},
#    {'itemcode': '251340',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150선물인버스',
#     'nowVal': 4370,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 1.39,
#     'nav': 4369.0,
#     'threeMonthEarnRate': -2.4887,
#     'quant': 38236111,
#     'amonut': 166267,
#     'marketSum': 5012},
#    {'itemcode': '229200',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥 150',
#     'nowVal': 14585,
#     'risefall': '5',
#     'changeVal': -195,
#     'changeRate': -1.32,
#     'nav': 14740.0,
#     'threeMonthEarnRate': 0.5373,
#     'quant': 3609424,
#     'amonut': 52677,
#     'marketSum': 4988},
#    {'itemcode': '294400',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200TR',
#     'nowVal': 51120,
#     'risefall': '2',
#     'changeVal': 195,
#     'changeRate': 0.38,
#     'nav': 51136.0,
#     'threeMonthEarnRate': -0.818,
#     'quant': 4911,
#     'amonut': 250,
#     'marketSum': 4959},
#    {'itemcode': '364960',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX BBIG K-뉴딜',
#     'nowVal': 13920,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.64,
#     'nav': 13926.0,
#     'threeMonthEarnRate': 10.6635,
#     'quant': 684583,
#     'amonut': 9549,
#     'marketSum': 4691},
#    {'itemcode': '381180',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국필라델피아반도체나스닥',
#     'nowVal': 10035,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -0.94,
#     'nav': None,
#     'threeMonthEarnRate': 4.2181,
#     'quant': 804439,
#     'amonut': 8039,
#     'marketSum': 4340},
#    {'itemcode': '360750',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500',
#     'nowVal': 12825,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.08,
#     'nav': None,
#     'threeMonthEarnRate': 9.2963,
#     'quant': 378510,
#     'amonut': 4854,
#     'marketSum': 4271},
#    {'itemcode': '332500',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 200TR',
#     'nowVal': 26225,
#     'risefall': '2',
#     'changeVal': 135,
#     'changeRate': 0.52,
#     'nav': 26229.0,
#     'threeMonthEarnRate': -1.0619,
#     'quant': 9191,
#     'amonut': 239,
#     'marketSum': 3829},
#    {'itemcode': '381170',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국테크TOP10 INDXX',
#     'nowVal': 11515,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -0.82,
#     'nav': None,
#     'threeMonthEarnRate': 14.7233,
#     'quant': 1932552,
#     'amonut': 22207,
#     'marketSum': 3748},
#    {'itemcode': '385540',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS종합채권(A-이상)액티브',
#     'nowVal': 101250,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.05,
#     'nav': 101232.0,
#     'threeMonthEarnRate': None,
#     'quant': 26,
#     'amonut': 2,
#     'marketSum': 3587},
#    {'itemcode': '290130',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR ESG사회책임투자',
#     'nowVal': 13900,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 13911.0,
#     'threeMonthEarnRate': -1.3275,
#     'quant': 34389,
#     'amonut': 476,
#     'marketSum': 3433},
#    {'itemcode': '091170',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 은행',
#     'nowVal': 7410,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 1.02,
#     'nav': 7440.0,
#     'threeMonthEarnRate': 1.9741,
#     'quant': 759702,
#     'amonut': 5603,
#     'marketSum': 3386},
#    {'itemcode': '226490',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스피',
#     'nowVal': 32580,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.15,
#     'nav': 32582.0,
#     'threeMonthEarnRate': 0.6809,
#     'quant': 17889,
#     'amonut': 579,
#     'marketSum': 3030},
#    {'itemcode': '282000',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 국고채3년선물인버스',
#     'nowVal': 99880,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.1,
#     'nav': 99871.0,
#     'threeMonthEarnRate': 0.2058,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 3025},
#    {'itemcode': '251350',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 선진국MSCI World',
#     'nowVal': 19870,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.03,
#     'nav': None,
#     'threeMonthEarnRate': 8.3401,
#     'quant': 30605,
#     'amonut': 608,
#     'marketSum': 3000},
#    {'itemcode': '295040',
#     'etfTabCode': 1,
#     'itemname': 'SMART 200TR',
#     'nowVal': 14615,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.21,
#     'nav': 14645.0,
#     'threeMonthEarnRate': -0.8498,
#     'quant': 13627,
#     'amonut': 198,
#     'marketSum': 2872},
#    {'itemcode': '367770',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn수소경제테마',
#     'nowVal': 12615,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.39,
#     'nav': 12625.0,
#     'threeMonthEarnRate': -0.0395,
#     'quant': 101488,
#     'amonut': 1279,
#     'marketSum': 2807},
#    {'itemcode': '272560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기국공채액티브',
#     'nowVal': 102095,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 102085.0,
#     'threeMonthEarnRate': 0.0882,
#     'quant': 494231,
#     'amonut': 50462,
#     'marketSum': 2792},
#    {'itemcode': '332940',
#     'etfTabCode': 1,
#     'itemname': 'HANARO MSCI Korea TR',
#     'nowVal': 17175,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.29,
#     'nav': 17279.0,
#     'threeMonthEarnRate': -1.487,
#     'quant': 335,
#     'amonut': 5,
#     'marketSum': 2782},
#    {'itemcode': '360200',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국S&P500',
#     'nowVal': 12920,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.04,
#     'nav': None,
#     'threeMonthEarnRate': 9.4027,
#     'quant': 244204,
#     'amonut': 3155,
#     'marketSum': 2752},
#    {'itemcode': '192090',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300',
#     'nowVal': 11215,
#     'risefall': '5',
#     'changeVal': -215,
#     'changeRate': -1.88,
#     'nav': None,
#     'threeMonthEarnRate': -0.6087,
#     'quant': 1004455,
#     'amonut': 11234,
#     'marketSum': 2736},
#    {'itemcode': '275980',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#     'nowVal': 18545,
#     'risefall': '5',
#     'changeVal': -195,
#     'changeRate': -1.04,
#     'nav': None,
#     'threeMonthEarnRate': 1.5442,
#     'quant': 72893,
#     'amonut': 1353,
#     'marketSum': 2578},
#    {'itemcode': '357870',
#     'etfTabCode': 7,
#     'itemname': 'TIGER CD금리투자KIS(합성)',
#     'nowVal': 50365,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 50366.0,
#     'threeMonthEarnRate': 0.169,
#     'quant': 40,
#     'amonut': 2,
#     'marketSum': 2530},
#    {'itemcode': '385550',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS단기종합채권(AA-이상)액티브',
#     'nowVal': 99980,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.02,
#     'nav': 99972.0,
#     'threeMonthEarnRate': None,
#     'quant': 48,
#     'amonut': 4,
#     'marketSum': 2507},
#    {'itemcode': '371160',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나항셍테크',
#     'nowVal': 8270,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.73,
#     'nav': None,
#     'threeMonthEarnRate': -22.4741,
#     'quant': 3587176,
#     'amonut': 29282,
#     'marketSum': 2456},
#    {'itemcode': '168580',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 중국본토CSI300',
#     'nowVal': 29950,
#     'risefall': '5',
#     'changeVal': -250,
#     'changeRate': -0.83,
#     'nav': None,
#     'threeMonthEarnRate': -1.3072,
#     'quant': 52416,
#     'amonut': 1562,
#     'marketSum': 2426},
#    {'itemcode': '261220',
#     'etfTabCode': 5,
#     'itemname': 'KODEX WTI원유선물(H)',
#     'nowVal': 10930,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.14,
#     'nav': None,
#     'threeMonthEarnRate': 16.7379,
#     'quant': 211241,
#     'amonut': 2305,
#     'marketSum': 2410},
#    {'itemcode': '132030',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 골드선물(H)',
#     'nowVal': 12250,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.62,
#     'nav': None,
#     'threeMonthEarnRate': 0.4123,
#     'quant': 98486,
#     'amonut': 1205,
#     'marketSum': 2377},
#    {'itemcode': '091160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 반도체',
#     'nowVal': 37600,
#     'risefall': '5',
#     'changeVal': -600,
#     'changeRate': -1.57,
#     'nav': 37643.0,
#     'threeMonthEarnRate': -4.8474,
#     'quant': 279095,
#     'amonut': 10504,
#     'marketSum': 2350},
#    {'itemcode': '196230',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기통안채',
#     'nowVal': 104490,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 104496.0,
#     'threeMonthEarnRate': 0.067,
#     'quant': 1632758,
#     'amonut': 170623,
#     'marketSum': 2296},
#    {'itemcode': '143850',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500선물(H)',
#     'nowVal': 51360,
#     'risefall': '5',
#     'changeVal': -140,
#     'changeRate': -0.27,
#     'nav': None,
#     'threeMonthEarnRate': 5.4571,
#     'quant': 87618,
#     'amonut': 4491,
#     'marketSum': 2234},
#    {'itemcode': '332930',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200TR',
#     'nowVal': 51165,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 0.27,
#     'nav': 51176.0,
#     'threeMonthEarnRate': -0.7489,
#     'quant': 100,
#     'amonut': 5,
#     'marketSum': 2226},
#    {'itemcode': '108450',
#     'etfTabCode': 2,
#     'itemname': 'KINDEX 삼성그룹섹터가중',
#     'nowVal': 17425,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 17494.0,
#     'threeMonthEarnRate': 5.2488,
#     'quant': 7045,
#     'amonut': 122,
#     'marketSum': 2056},
#    {'itemcode': '245710',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 베트남VN30(합성)',
#     'nowVal': 20780,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.34,
#     'nav': None,
#     'threeMonthEarnRate': 14.1527,
#     'quant': 35863,
#     'amonut': 746,
#     'marketSum': 2036},
#    {'itemcode': '161510',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 고배당주',
#     'nowVal': 12550,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.76,
#     'nav': 12581.0,
#     'threeMonthEarnRate': 1.823,
#     'quant': 94654,
#     'amonut': 1185,
#     'marketSum': 2029},
#    {'itemcode': '272580',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기채권액티브',
#     'nowVal': 50110,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.01,
#     'nav': 50111.0,
#     'threeMonthEarnRate': 0.0299,
#     'quant': 3817,
#     'amonut': 191,
#     'marketSum': 2019},
#    {'itemcode': '232080',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스닥150',
#     'nowVal': 14810,
#     'risefall': '5',
#     'changeVal': -210,
#     'changeRate': -1.4,
#     'nav': 14946.0,
#     'threeMonthEarnRate': 0.6769,
#     'quant': 189335,
#     'amonut': 2808,
#     'marketSum': 1982},
#    {'itemcode': '190620',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 단기통안채',
#     'nowVal': 100375,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100370.0,
#     'threeMonthEarnRate': 0.0947,
#     'quant': 1693,
#     'amonut': 169,
#     'marketSum': 1929},
#    {'itemcode': '367380',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국나스닥100',
#     'nowVal': 13290,
#     'risefall': '5',
#     'changeVal': -100,
#     'changeRate': -0.75,
#     'nav': None,
#     'threeMonthEarnRate': 11.7229,
#     'quant': 199024,
#     'amonut': 2645,
#     'marketSum': 1900},
#    {'itemcode': '302450',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스피',
#     'nowVal': 32585,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.06,
#     'nav': 32574.0,
#     'threeMonthEarnRate': 0.5123,
#     'quant': 63,
#     'amonut': 2,
#     'marketSum': 1890},
#    {'itemcode': '278240',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150선물레버리지',
#     'nowVal': 15720,
#     'risefall': '5',
#     'changeVal': -405,
#     'changeRate': -2.51,
#     'nav': 15721.0,
#     'threeMonthEarnRate': 1.7029,
#     'quant': 44597,
#     'amonut': 701,
#     'marketSum': 1797},
#    {'itemcode': '390950',
#     'etfTabCode': 6,
#     'itemname': 'HANARO 단기채권액티브',
#     'nowVal': 100090,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100091.0,
#     'threeMonthEarnRate': None,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 1746},
#    {'itemcode': '143860',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 헬스케어',
#     'nowVal': 43205,
#     'risefall': '5',
#     'changeVal': -295,
#     'changeRate': -0.68,
#     'nav': 43411.0,
#     'threeMonthEarnRate': -4.5111,
#     'quant': 12391,
#     'amonut': 537,
#     'marketSum': 1711},
#    {'itemcode': '270810',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150',
#     'nowVal': 14505,
#     'risefall': '5',
#     'changeVal': -215,
#     'changeRate': -1.46,
#     'nav': 14652.0,
#     'threeMonthEarnRate': 0.8288,
#     'quant': 7732,
#     'amonut': 112,
#     'marketSum': 1665},
#    {'itemcode': '394670',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#     'nowVal': 10260,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -1.01,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 2283255,
#     'amonut': 23202,
#     'marketSum': 1625},
#    {'itemcode': '150460',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 중국소비테마',
#     'nowVal': 8985,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.44,
#     'nav': 9004.0,
#     'threeMonthEarnRate': 6.3015,
#     'quant': 59591,
#     'amonut': 535,
#     'marketSum': 1598},
#    {'itemcode': '326240',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR IT플러스',
#     'nowVal': 22870,
#     'risefall': '5',
#     'changeVal': -110,
#     'changeRate': -0.48,
#     'nav': 22874.0,
#     'threeMonthEarnRate': 3.5508,
#     'quant': 183562,
#     'amonut': 4188,
#     'marketSum': 1592},
#    {'itemcode': '136340',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 중기우량회사채',
#     'nowVal': 105100,
#     'risefall': '5',
#     'changeVal': -180,
#     'changeRate': -0.17,
#     'nav': 105139.0,
#     'threeMonthEarnRate': -0.1802,
#     'quant': 174,
#     'amonut': 18,
#     'marketSum': 1555},
#    {'itemcode': '182480',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#     'nowVal': 15340,
#     'risefall': '2',
#     'changeVal': 135,
#     'changeRate': 0.89,
#     'nav': None,
#     'threeMonthEarnRate': 8.6071,
#     'quant': 54044,
#     'amonut': 825,
#     'marketSum': 1457},
#    {'itemcode': '091230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 반도체',
#     'nowVal': 38535,
#     'risefall': '5',
#     'changeVal': -665,
#     'changeRate': -1.7,
#     'nav': 38537.0,
#     'threeMonthEarnRate': -4.7388,
#     'quant': 62823,
#     'amonut': 2419,
#     'marketSum': 1387},
#    {'itemcode': '148070',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 국고채10년',
#     'nowVal': 122615,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 0.09,
#     'nav': 122515.0,
#     'threeMonthEarnRate': 1.8965,
#     'quant': 5094,
#     'amonut': 623,
#     'marketSum': 1373},
#    {'itemcode': '138540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 현대차그룹+펀더멘털',
#     'nowVal': 27235,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.06,
#     'nav': 27324.0,
#     'threeMonthEarnRate': 1.9034,
#     'quant': 21028,
#     'amonut': 572,
#     'marketSum': 1356},
#    {'itemcode': '298770',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 한국대만IT프리미어',
#     'nowVal': 20130,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -0.57,
#     'nav': None,
#     'threeMonthEarnRate': -2.2689,
#     'quant': 33871,
#     'amonut': 683,
#     'marketSum': 1329},
#    {'itemcode': '367760',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn5G테크',
#     'nowVal': 11370,
#     'risefall': '5',
#     'changeVal': -100,
#     'changeRate': -0.87,
#     'nav': 11374.0,
#     'threeMonthEarnRate': -1.0183,
#     'quant': 76469,
#     'amonut': 869,
#     'marketSum': 1234},
#    {'itemcode': '328370',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스피TR',
#     'nowVal': 16145,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.55,
#     'nav': 16260.0,
#     'threeMonthEarnRate': 0.4019,
#     'quant': 861523,
#     'amonut': 13968,
#     'marketSum': 1227},
#    {'itemcode': '219480',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500선물(H)',
#     'nowVal': 21135,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.28,
#     'nav': None,
#     'threeMonthEarnRate': 5.4739,
#     'quant': 24311,
#     'amonut': 513,
#     'marketSum': 1215},
#    {'itemcode': '372330',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나항셍테크',
#     'nowVal': 8305,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.91,
#     'nav': None,
#     'threeMonthEarnRate': -22.3219,
#     'quant': 1373661,
#     'amonut': 11249,
#     'marketSum': 1200},
#    {'itemcode': '283580',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 중국본토CSI300',
#     'nowVal': 13595,
#     'risefall': '5',
#     'changeVal': -215,
#     'changeRate': -1.56,
#     'nav': None,
#     'threeMonthEarnRate': -0.576,
#     'quant': 193704,
#     'amonut': 2623,
#     'marketSum': 1196},
#    {'itemcode': '252710',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물인버스2X',
#     'nowVal': 2005,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.25,
#     'nav': 2004.0,
#     'threeMonthEarnRate': 0.0,
#     'quant': 4151154,
#     'amonut': 8368,
#     'marketSum': 1151},
#    {'itemcode': '273140',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기변동금리부채권액티브',
#     'nowVal': 102620,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 102620.0,
#     'threeMonthEarnRate': 0.0877,
#     'quant': 1977,
#     'amonut': 202,
#     'marketSum': 1140},
#    {'itemcode': '325010',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Fn성장',
#     'nowVal': 18795,
#     'risefall': '5',
#     'changeVal': -80,
#     'changeRate': -0.42,
#     'nav': 18772.0,
#     'threeMonthEarnRate': 1.1142,
#     'quant': 1074,
#     'amonut': 20,
#     'marketSum': 1090},
#    {'itemcode': '225040',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#     'nowVal': 33000,
#     'risefall': '5',
#     'changeVal': -160,
#     'changeRate': -0.48,
#     'nav': None,
#     'threeMonthEarnRate': 9.6017,
#     'quant': 13453,
#     'amonut': 443,
#     'marketSum': 1089},
#    {'itemcode': '204480',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#     'nowVal': 28490,
#     'risefall': '5',
#     'changeVal': -1005,
#     'changeRate': -3.41,
#     'nav': None,
#     'threeMonthEarnRate': -3.406,
#     'quant': 387545,
#     'amonut': 10881,
#     'marketSum': 1083},
#    {'itemcode': '139280',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 경기방어',
#     'nowVal': 12350,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.24,
#     'nav': 12349.0,
#     'threeMonthEarnRate': -1.2742,
#     'quant': 19155,
#     'amonut': 235,
#     'marketSum': 1050},
#    {'itemcode': '144600',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 은선물(H)',
#     'nowVal': 5120,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -1.44,
#     'nav': None,
#     'threeMonthEarnRate': -4.1513,
#     'quant': 549369,
#     'amonut': 2799,
#     'marketSum': 1044},
#    {'itemcode': '329200',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 부동산인프라고배당',
#     'nowVal': 5880,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.34,
#     'nav': 5890.0,
#     'threeMonthEarnRate': 4.6428,
#     'quant': 102637,
#     'amonut': 602,
#     'marketSum': 1044},
#    {'itemcode': '368590',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국나스닥100',
#     'nowVal': 12865,
#     'risefall': '5',
#     'changeVal': -80,
#     'changeRate': -0.62,
#     'nav': None,
#     'threeMonthEarnRate': 11.5467,
#     'quant': 71677,
#     'amonut': 921,
#     'marketSum': 1003},
#    {'itemcode': '156080',
#     'etfTabCode': 1,
#     'itemname': 'KODEX MSCI Korea',
#     'nowVal': 19900,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -0.62,
#     'nav': 20055.0,
#     'threeMonthEarnRate': -1.3839,
#     'quant': 59,
#     'amonut': 1,
#     'marketSum': 995},
#    {'itemcode': '325020',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 배당가치',
#     'nowVal': 13690,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.48,
#     'nav': 13687.0,
#     'threeMonthEarnRate': -0.8659,
#     'quant': 3666,
#     'amonut': 50,
#     'marketSum': 986},
#    {'itemcode': '228800',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 여행레저',
#     'nowVal': 5355,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.19,
#     'nav': 5358.0,
#     'threeMonthEarnRate': 13.9658,
#     'quant': 333195,
#     'amonut': 1775,
#     'marketSum': 959},
#    {'itemcode': '139220',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 건설',
#     'nowVal': 3375,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.75,
#     'nav': 3374.0,
#     'threeMonthEarnRate': 3.5548,
#     'quant': 696657,
#     'amonut': 2345,
#     'marketSum': 954},
#    {'itemcode': '117700',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 건설',
#     'nowVal': 3875,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.52,
#     'nav': 3894.0,
#     'threeMonthEarnRate': 2.6631,
#     'quant': 424800,
#     'amonut': 1645,
#     'marketSum': 953},
#    {'itemcode': '371470',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나바이오테크SOLACTIVE',
#     'nowVal': 11770,
#     'risefall': '2',
#     'changeVal': 160,
#     'changeRate': 1.38,
#     'nav': None,
#     'threeMonthEarnRate': -5.6098,
#     'quant': 341910,
#     'amonut': 3915,
#     'marketSum': 951},
#    {'itemcode': '376410',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 탄소효율그린뉴딜',
#     'nowVal': 10315,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.15,
#     'nav': 10347.0,
#     'threeMonthEarnRate': -0.145,
#     'quant': 12385,
#     'amonut': 127,
#     'marketSum': 949},
#    {'itemcode': '322400',
#     'etfTabCode': 2,
#     'itemname': 'HANARO e커머스',
#     'nowVal': 20470,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.44,
#     'nav': 20471.0,
#     'threeMonthEarnRate': 11.6541,
#     'quant': 144090,
#     'amonut': 2944,
#     'marketSum': 942},
#    {'itemcode': '114260',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채3년',
#     'nowVal': 57975,
#     'risefall': '5',
#     'changeVal': -100,
#     'changeRate': -0.17,
#     'nav': 58007.0,
#     'threeMonthEarnRate': 0.0,
#     'quant': 468,
#     'amonut': 27,
#     'marketSum': 939},
#    {'itemcode': '267770',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물레버리지',
#     'nowVal': 21140,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.45,
#     'nav': 21137.0,
#     'threeMonthEarnRate': -1.8424,
#     'quant': 700759,
#     'amonut': 14750,
#     'marketSum': 930},
#    {'itemcode': '364970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX바이오K-뉴딜',
#     'nowVal': 10385,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -1.14,
#     'nav': 10413.0,
#     'threeMonthEarnRate': 1.4485,
#     'quant': 105582,
#     'amonut': 1102,
#     'marketSum': 929},
#    {'itemcode': '387280',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 퓨처모빌리티액티브',
#     'nowVal': 10980,
#     'risefall': '5',
#     'changeVal': -110,
#     'changeRate': -0.99,
#     'nav': 10992.0,
#     'threeMonthEarnRate': None,
#     'quant': 83333,
#     'amonut': 917,
#     'marketSum': 925},
#    {'itemcode': '122260',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 통안채1년',
#     'nowVal': 101215,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.02,
#     'nav': 101222.0,
#     'threeMonthEarnRate': -0.0543,
#     'quant': 21503,
#     'amonut': 2176,
#     'marketSum': 921},
#    {'itemcode': '379800',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500TR',
#     'nowVal': 11180,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.18,
#     'nav': None,
#     'threeMonthEarnRate': 9.2511,
#     'quant': 126442,
#     'amonut': 1412,
#     'marketSum': 872},
#    {'itemcode': '233160',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스닥150 레버리지',
#     'nowVal': 16370,
#     'risefall': '5',
#     'changeVal': -440,
#     'changeRate': -2.62,
#     'nav': 16529.0,
#     'threeMonthEarnRate': 0.87,
#     'quant': 288153,
#     'amonut': 4755,
#     'marketSum': 851},
#    {'itemcode': '368190',
#     'etfTabCode': 2,
#     'itemname': 'HANARO Fn K-뉴딜디지털플러스',
#     'nowVal': 13625,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.62,
#     'nav': 13628.0,
#     'threeMonthEarnRate': 5.4615,
#     'quant': 18548,
#     'amonut': 252,
#     'marketSum': 845},
#    {'itemcode': '309230',
#     'etfTabCode': 2,
#     'itemname': 'KINDEX 미국WideMoat가치주',
#     'nowVal': 17390,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.32,
#     'nav': None,
#     'threeMonthEarnRate': 7.2047,
#     'quant': 102898,
#     'amonut': 1792,
#     'marketSum': 817},
#    {'itemcode': '195930',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 유로스탁스50(합성 H)',
#     'nowVal': 13815,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.36,
#     'nav': None,
#     'threeMonthEarnRate': 1.9485,
#     'quant': 279850,
#     'amonut': 3857,
#     'marketSum': 815},
#    {'itemcode': '304940',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100선물(H)',
#     'nowVal': 18960,
#     'risefall': '5',
#     'changeVal': -205,
#     'changeRate': -1.07,
#     'nav': None,
#     'threeMonthEarnRate': 7.5175,
#     'quant': 40811,
#     'amonut': 773,
#     'marketSum': 806},
#    {'itemcode': '261240',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물',
#     'nowVal': 10235,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.39,
#     'nav': 10237.0,
#     'threeMonthEarnRate': 3.6077,
#     'quant': 135683,
#     'amonut': 1388,
#     'marketSum': 794},
#    {'itemcode': '266160',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 고배당',
#     'nowVal': 12865,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.55,
#     'nav': 12905.0,
#     'threeMonthEarnRate': -0.0391,
#     'quant': 16348,
#     'amonut': 209,
#     'marketSum': 791},
#    {'itemcode': '385520',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-미래차액티브',
#     'nowVal': 10845,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.5,
#     'nav': 10848.0,
#     'threeMonthEarnRate': None,
#     'quant': 69921,
#     'amonut': 756,
#     'marketSum': 775},
#    {'itemcode': '157490',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 소프트웨어',
#     'nowVal': 19250,
#     'risefall': '5',
#     'changeVal': -160,
#     'changeRate': -0.82,
#     'nav': 19254.0,
#     'threeMonthEarnRate': 10.034,
#     'quant': 53349,
#     'amonut': 1027,
#     'marketSum': 774},
#    {'itemcode': '379810',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100TR',
#     'nowVal': 11365,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.61,
#     'nav': None,
#     'threeMonthEarnRate': 11.6699,
#     'quant': 231179,
#     'amonut': 2625,
#     'marketSum': 761},
#    {'itemcode': '174360',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 중국본토대형주CSI100',
#     'nowVal': 20040,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -0.47,
#     'nav': None,
#     'threeMonthEarnRate': -6.5878,
#     'quant': 43703,
#     'amonut': 873,
#     'marketSum': 741},
#    {'itemcode': '130680',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 원유선물Enhanced(H)',
#     'nowVal': 3300,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.15,
#     'nav': None,
#     'threeMonthEarnRate': 16.431,
#     'quant': 97845,
#     'amonut': 322,
#     'marketSum': 731},
#    {'itemcode': '195980',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#     'nowVal': 12020,
#     'risefall': '5',
#     'changeVal': -150,
#     'changeRate': -1.23,
#     'nav': None,
#     'threeMonthEarnRate': -6.2043,
#     'quant': 42064,
#     'amonut': 504,
#     'marketSum': 704},
#    {'itemcode': '256750',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 심천ChiNext(합성)',
#     'nowVal': 14230,
#     'risefall': '5',
#     'changeVal': -340,
#     'changeRate': -2.33,
#     'nav': None,
#     'threeMonthEarnRate': 14.0062,
#     'quant': 152855,
#     'amonut': 2152,
#     'marketSum': 683},
#    {'itemcode': '245340',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국다우존스30',
#     'nowVal': 20460,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.32,
#     'nav': None,
#     'threeMonthEarnRate': 6.948,
#     'quant': 17085,
#     'amonut': 349,
#     'marketSum': 675},
#    {'itemcode': '114820',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국채3년',
#     'nowVal': 110530,
#     'risefall': '5',
#     'changeVal': -165,
#     'changeRate': -0.15,
#     'nav': 110604.0,
#     'threeMonthEarnRate': 0.0045,
#     'quant': 1077,
#     'amonut': 119,
#     'marketSum': 663},
#    {'itemcode': '277630',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스피',
#     'nowVal': 32750,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -0.29,
#     'nav': 32870.0,
#     'threeMonthEarnRate': 0.665,
#     'quant': 2094,
#     'amonut': 68,
#     'marketSum': 655},
#    {'itemcode': '306520',
#     'etfTabCode': 3,
#     'itemname': 'HANARO 200선물인버스',
#     'nowVal': 8660,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.23,
#     'nav': 8659.0,
#     'threeMonthEarnRate': 0.2888,
#     'quant': 1803,
#     'amonut': 15,
#     'marketSum': 641},
#    {'itemcode': '363510',
#     'etfTabCode': 6,
#     'itemname': 'SMART KIS단기통안채',
#     'nowVal': 100330,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100357.0,
#     'threeMonthEarnRate': 0.0398,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 630},
#    {'itemcode': '091220',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 은행',
#     'nowVal': 7730,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 1.24,
#     'nav': 7757.0,
#     'threeMonthEarnRate': 1.5562,
#     'quant': 23817,
#     'amonut': 183,
#     'marketSum': 628},
#    {'itemcode': '266370',
#     'etfTabCode': 2,
#     'itemname': 'KODEX IT',
#     'nowVal': 21055,
#     'risefall': '5',
#     'changeVal': -160,
#     'changeRate': -0.75,
#     'nav': 21119.0,
#     'threeMonthEarnRate': -2.1539,
#     'quant': 8382,
#     'amonut': 175,
#     'marketSum': 611},
#    {'itemcode': '289260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER MSCI KOREA ESG리더스',
#     'nowVal': 12155,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.53,
#     'nav': 12206.0,
#     'threeMonthEarnRate': -1.396,
#     'quant': 257,
#     'amonut': 3,
#     'marketSum': 605},
#    {'itemcode': '394660',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#     'nowVal': 10320,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.58,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 607282,
#     'amonut': 6269,
#     'marketSum': 603},
#    {'itemcode': '329750',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국달러단기채권액티브',
#     'nowVal': 9885,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.3,
#     'nav': None,
#     'threeMonthEarnRate': 3.5189,
#     'quant': 46827,
#     'amonut': 463,
#     'marketSum': 598},
#    {'itemcode': '336160',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 금융채액티브',
#     'nowVal': 102980,
#     'risefall': '5',
#     'changeVal': -155,
#     'changeRate': -0.15,
#     'nav': 102985.0,
#     'threeMonthEarnRate': -0.3623,
#     'quant': 54,
#     'amonut': 5,
#     'marketSum': 597},
#    {'itemcode': '117680',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 철강',
#     'nowVal': 10555,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.19,
#     'nav': 10585.0,
#     'threeMonthEarnRate': -2.9372,
#     'quant': 214683,
#     'amonut': 2272,
#     'marketSum': 591},
#    {'itemcode': '365000',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX인터넷K-뉴딜',
#     'nowVal': 12820,
#     'risefall': '5',
#     'changeVal': -135,
#     'changeRate': -1.04,
#     'nav': 12848.0,
#     'threeMonthEarnRate': 12.019,
#     'quant': 162347,
#     'amonut': 2089,
#     'marketSum': 590},
#    {'itemcode': '305080',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국채10년선물',
#     'nowVal': 12020,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.54,
#     'nav': None,
#     'threeMonthEarnRate': 6.031,
#     'quant': 62341,
#     'amonut': 750,
#     'marketSum': 589},
#    {'itemcode': '228810',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 미디어컨텐츠',
#     'nowVal': 8495,
#     'risefall': '5',
#     'changeVal': -135,
#     'changeRate': -1.56,
#     'nav': 8499.0,
#     'threeMonthEarnRate': 23.5504,
#     'quant': 305570,
#     'amonut': 2609,
#     'marketSum': 584},
#    {'itemcode': '245360',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나HSCEI',
#     'nowVal': 11120,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.45,
#     'nav': None,
#     'threeMonthEarnRate': -13.3464,
#     'quant': 137368,
#     'amonut': 1517,
#     'marketSum': 578},
#    {'itemcode': '102970',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 증권',
#     'nowVal': 8290,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.06,
#     'nav': 8290.0,
#     'threeMonthEarnRate': -7.2021,
#     'quant': 157147,
#     'amonut': 1303,
#     'marketSum': 576},
#    {'itemcode': '315960',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 대형고배당10TR',
#     'nowVal': 16680,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.09,
#     'nav': 16699.0,
#     'threeMonthEarnRate': -4.2718,
#     'quant': 4314,
#     'amonut': 71,
#     'marketSum': 575},
#    {'itemcode': '387270',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌BBIG액티브',
#     'nowVal': 11270,
#     'risefall': '5',
#     'changeVal': -160,
#     'changeRate': -1.4,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 148021,
#     'amonut': 1667,
#     'marketSum': 575},
#    {'itemcode': '361580',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200TR',
#     'nowVal': 22045,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.27,
#     'nav': 22045.0,
#     'threeMonthEarnRate': -0.5879,
#     'quant': 2474,
#     'amonut': 54,
#     'marketSum': 573},
#    {'itemcode': '329650',
#     'etfTabCode': 7,
#     'itemname': 'KODEX TRF3070',
#     'nowVal': 11425,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.13,
#     'nav': 11381.0,
#     'threeMonthEarnRate': 2.9318,
#     'quant': 43139,
#     'amonut': 492,
#     'marketSum': 571},
#    {'itemcode': '123310',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 인버스',
#     'nowVal': 4165,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 4164.0,
#     'threeMonthEarnRate': 0.2406,
#     'quant': 211281,
#     'amonut': 881,
#     'marketSum': 571},
#    {'itemcode': '304780',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200선물레버리지',
#     'nowVal': 30710,
#     'risefall': '2',
#     'changeVal': 160,
#     'changeRate': 0.52,
#     'nav': 30695.0,
#     'threeMonthEarnRate': -1.8159,
#     'quant': 1282,
#     'amonut': 38,
#     'marketSum': 553},
#    {'itemcode': '139230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 중공업',
#     'nowVal': 3775,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 3786.0,
#     'threeMonthEarnRate': 8.0114,
#     'quant': 285353,
#     'amonut': 1078,
#     'marketSum': 551},
#    {'itemcode': '363580',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200IT TR',
#     'nowVal': 14455,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.34,
#     'nav': 14547.0,
#     'threeMonthEarnRate': -4.5096,
#     'quant': 2356,
#     'amonut': 34,
#     'marketSum': 549},
#    {'itemcode': '130730',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 단기자금',
#     'nowVal': 101140,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 101134.0,
#     'threeMonthEarnRate': 0.0742,
#     'quant': 1486214,
#     'amonut': 150323,
#     'marketSum': 534},
#    {'itemcode': '354350',
#     'etfTabCode': 4,
#     'itemname': 'HANARO 글로벌럭셔리S&P(합성)',
#     'nowVal': 18010,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.39,
#     'nav': None,
#     'threeMonthEarnRate': 4.1474,
#     'quant': 11745,
#     'amonut': 212,
#     'marketSum': 531},
#    {'itemcode': '375770',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 탄소효율그린뉴딜',
#     'nowVal': 10330,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.15,
#     'nav': 10330.0,
#     'threeMonthEarnRate': -0.3382,
#     'quant': 5878,
#     'amonut': 60,
#     'marketSum': 517},
#    {'itemcode': '385510',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-신재생에너지액티브',
#     'nowVal': 10860,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.64,
#     'nav': 10860.0,
#     'threeMonthEarnRate': None,
#     'quant': 78765,
#     'amonut': 852,
#     'marketSum': 516},
#    {'itemcode': '371450',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌클라우드컴퓨팅INDXX',
#     'nowVal': 11565,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -0.81,
#     'nav': None,
#     'threeMonthEarnRate': 6.193,
#     'quant': 40298,
#     'amonut': 464,
#     'marketSum': 509},
#    {'itemcode': '385560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS국고채30년Enhanced',
#     'nowVal': 109955,
#     'risefall': '2',
#     'changeVal': 160,
#     'changeRate': 0.15,
#     'nav': 109846.0,
#     'threeMonthEarnRate': None,
#     'quant': 52,
#     'amonut': 5,
#     'marketSum': 506},
#    {'itemcode': '302190',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 중장기국채',
#     'nowVal': 52720,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.11,
#     'nav': 52747.0,
#     'threeMonthEarnRate': 0.995,
#     'quant': 126,
#     'amonut': 6,
#     'marketSum': 485},
#    {'itemcode': '337140',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 코스피대형주',
#     'nowVal': 15105,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.07,
#     'nav': 15170.0,
#     'threeMonthEarnRate': -0.9645,
#     'quant': 5052,
#     'amonut': 76,
#     'marketSum': 483},
#    {'itemcode': '292190',
#     'etfTabCode': 1,
#     'itemname': 'KODEX KRX300',
#     'nowVal': 19710,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.15,
#     'nav': 19764.0,
#     'threeMonthEarnRate': -0.6593,
#     'quant': 4056,
#     'amonut': 79,
#     'marketSum': 473},
#    {'itemcode': '266360',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 미디어&엔터테인먼트',
#     'nowVal': 26215,
#     'risefall': '5',
#     'changeVal': -215,
#     'changeRate': -0.81,
#     'nav': 26255.0,
#     'threeMonthEarnRate': 14.3908,
#     'quant': 13094,
#     'amonut': 344,
#     'marketSum': 472},
#    {'itemcode': '243880',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200IT레버리지',
#     'nowVal': 67135,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.03,
#     'nav': 67260.0,
#     'threeMonthEarnRate': -8.3379,
#     'quant': 7025,
#     'amonut': 468,
#     'marketSum': 470},
#    {'itemcode': '219390',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국S&P원유생산기업(합성 H)',
#     'nowVal': 3750,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -1.32,
#     'nav': None,
#     'threeMonthEarnRate': 7.8014,
#     'quant': 155011,
#     'amonut': 577,
#     'marketSum': 469},
#    {'itemcode': '114460',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국고채3년',
#     'nowVal': 106595,
#     'risefall': '5',
#     'changeVal': -160,
#     'changeRate': -0.15,
#     'nav': 106645.0,
#     'threeMonthEarnRate': -0.0375,
#     'quant': 11,
#     'amonut': 1,
#     'marketSum': 416},
#    {'itemcode': '337160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200ESG',
#     'nowVal': 15335,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.13,
#     'nav': 15349.0,
#     'threeMonthEarnRate': -0.6359,
#     'quant': 1988,
#     'amonut': 30,
#     'marketSum': 414},
#    {'itemcode': '326230',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 내수주플러스',
#     'nowVal': 11070,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.32,
#     'nav': 11086.0,
#     'threeMonthEarnRate': -1.0137,
#     'quant': 15585,
#     'amonut': 172,
#     'marketSum': 407},
#    {'itemcode': '280930',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국러셀2000(H)',
#     'nowVal': 14275,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.45,
#     'nav': None,
#     'threeMonthEarnRate': -4.2405,
#     'quant': 7626,
#     'amonut': 108,
#     'marketSum': 400},
#    {'itemcode': '256440',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 인도네시아MSCI(합성)',
#     'nowVal': 7770,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -1.21,
#     'nav': None,
#     'threeMonthEarnRate': -2.2982,
#     'quant': 27369,
#     'amonut': 214,
#     'marketSum': 396},
#    {'itemcode': '356540',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX KIS종합채권(AA-이상)액티브',
#     'nowVal': 99165,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -0.11,
#     'nav': 99231.0,
#     'threeMonthEarnRate': 1.1668,
#     'quant': 2,
#     'amonut': 0,
#     'marketSum': 381},
#    {'itemcode': '244580',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 바이오',
#     'nowVal': 14575,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -0.65,
#     'nav': 14746.0,
#     'threeMonthEarnRate': -4.3677,
#     'quant': 109650,
#     'amonut': 1606,
#     'marketSum': 373},
#    {'itemcode': '304770',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 코스닥150',
#     'nowVal': 14605,
# ...
#     'nowVal': 49270,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.18,
#     'nav': 49307.0,
#     'threeMonthEarnRate': 1.3916,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 59},
#    {'itemcode': '267440',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물(H)',
#     'nowVal': 11815,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.34,
#     'nav': None,
#     'threeMonthEarnRate': 4.7597,
#     'quant': 84,
#     'amonut': 0,
#     'marketSum': 59},
#    {'itemcode': '290080',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200고배당커버드콜ATM',
#     'nowVal': 8375,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.96,
#     'nav': 8364.0,
#     'threeMonthEarnRate': 6.3461,
#     'quant': 45,
#     'amonut': 0,
#     'marketSum': 59},
#    {'itemcode': '217790',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 가격조정',
#     'nowVal': 26505,
#     'risefall': '5',
#     'changeVal': -295,
#     'changeRate': -1.1,
#     'nav': 26510.0,
#     'threeMonthEarnRate': -1.2746,
#     'quant': 45,
#     'amonut': 1,
#     'marketSum': 58},
#    {'itemcode': '269530',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG S&P글로벌인프라',
#     'nowVal': 11560,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.17,
#     'nav': None,
#     'threeMonthEarnRate': 3.0357,
#     'quant': 41,
#     'amonut': 0,
#     'marketSum': 58},
#    {'itemcode': '304670',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국채울트라30년선물인버스(H)',
#     'nowVal': 7225,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.76,
#     'nav': None,
#     'threeMonthEarnRate': -6.8459,
#     'quant': 24841,
#     'amonut': 180,
#     'marketSum': 58},
#    {'itemcode': '302180',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국채선물10년인버스',
#     'nowVal': 47645,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 47564.0,
#     'threeMonthEarnRate': -2.0356,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 57},
#    {'itemcode': '261260',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물인버스2X',
#     'nowVal': 9300,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.69,
#     'nav': 9302.0,
#     'threeMonthEarnRate': -7.369,
#     'quant': 15828,
#     'amonut': 146,
#     'marketSum': 56},
#    {'itemcode': '291680',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 차이나H선물인버스(H)',
#     'nowVal': 11015,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.09,
#     'nav': None,
#     'threeMonthEarnRate': 17.7884,
#     'quant': 2090,
#     'amonut': 23,
#     'marketSum': 55},
#    {'itemcode': '321410',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 멀티에셋하이인컴(H)',
#     'nowVal': 10990,
#     'risefall': '2',
#     'changeVal': 110,
#     'changeRate': 1.01,
#     'nav': None,
#     'threeMonthEarnRate': 2.7869,
#     'quant': 66,
#     'amonut': 0,
#     'marketSum': 55},
#    {'itemcode': '140570',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 수출주',
#     'nowVal': 13690,
#     'risefall': '5',
#     'changeVal': -80,
#     'changeRate': -0.58,
#     'nav': 13745.0,
#     'threeMonthEarnRate': 2.8763,
#     'quant': 116,
#     'amonut': 1,
#     'marketSum': 55},
#    {'itemcode': '333950',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KS로우사이즈가중TR',
#     'nowVal': 18095,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 18088.0,
#     'threeMonthEarnRate': 3.4887,
#     'quant': 20,
#     'amonut': 0,
#     'marketSum': 54},
#    {'itemcode': '269370',
#     'etfTabCode': 4,
#     'itemname': 'TIGER S&P글로벌인프라(합성)',
#     'nowVal': 10800,
#     'risefall': '2',
#     'changeVal': 110,
#     'changeRate': 1.03,
#     'nav': None,
#     'threeMonthEarnRate': 2.3456,
#     'quant': 943,
#     'amonut': 10,
#     'marketSum': 54},
#    {'itemcode': '285010',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200중공업',
#     'nowVal': 11700,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.17,
#     'nav': 11700.0,
#     'threeMonthEarnRate': 9.0569,
#     'quant': 2621,
#     'amonut': 30,
#     'marketSum': 54},
#    {'itemcode': '371150',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 차이나항셍테크',
#     'nowVal': 8240,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.43,
#     'nav': None,
#     'threeMonthEarnRate': -22.5944,
#     'quant': 171542,
#     'amonut': 1403,
#     'marketSum': 54},
#    {'itemcode': '157500',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 증권',
#     'nowVal': 4830,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.1,
#     'nav': 4843.0,
#     'threeMonthEarnRate': -7.2867,
#     'quant': 5917,
#     'amonut': 28,
#     'marketSum': 53},
#    {'itemcode': '250730',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 차이나HSCEI(H)',
#     'nowVal': 10380,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.19,
#     'nav': None,
#     'threeMonthEarnRate': -17.0985,
#     'quant': 64782,
#     'amonut': 664,
#     'marketSum': 52},
#    {'itemcode': '261920',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 필리핀MSCI(합성)',
#     'nowVal': 12775,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -0.74,
#     'nav': None,
#     'threeMonthEarnRate': 2.6725,
#     'quant': 986,
#     'amonut': 12,
#     'marketSum': 51},
#    {'itemcode': '292770',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국채선물3년인버스',
#     'nowVal': 49770,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 49813.0,
#     'threeMonthEarnRate': 0.1408,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 51},
#    {'itemcode': '220130',
#     'etfTabCode': 4,
#     'itemname': 'SMART 중국본토 중소형 CSI500(합성 H)',
#     'nowVal': 5615,
#     'risefall': '5',
#     'changeVal': -185,
#     'changeRate': -3.19,
#     'nav': None,
#     'threeMonthEarnRate': 8.3099,
#     'quant': 7633,
#     'amonut': 42,
#     'marketSum': 51},
#    {'itemcode': '280920',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 주도업종',
#     'nowVal': 12535,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.12,
#     'nav': 12522.0,
#     'threeMonthEarnRate': 3.2327,
#     'quant': 2358,
#     'amonut': 29,
#     'marketSum': 50},
#    {'itemcode': '299080',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국채선물3년인버스',
#     'nowVal': 99560,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 99614.0,
#     'threeMonthEarnRate': 0.2365,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 50},
#    {'itemcode': '261270',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물인버스',
#     'nowVal': 9910,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.3,
#     'nav': 9915.0,
#     'threeMonthEarnRate': -3.7289,
#     'quant': 2400,
#     'amonut': 23,
#     'marketSum': 50},
#    {'itemcode': '278420',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG우수기업',
#     'nowVal': 9895,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.35,
#     'nav': 9926.0,
#     'threeMonthEarnRate': 3.675,
#     'quant': 1481,
#     'amonut': 14,
#     'marketSum': 49},
#    {'itemcode': '139310',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 금속선물(H)',
#     'nowVal': 6995,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.71,
#     'nav': None,
#     'threeMonthEarnRate': 3.7555,
#     'quant': 10484,
#     'amonut': 73,
#     'marketSum': 49},
#    {'itemcode': '266550',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 중형주저변동50',
#     'nowVal': 12215,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.04,
#     'nav': 12224.0,
#     'threeMonthEarnRate': 3.2356,
#     'quant': 414,
#     'amonut': 5,
#     'marketSum': 49},
#    {'itemcode': '295820',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200동일가중',
#     'nowVal': 12175,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.08,
#     'nav': 12171.0,
#     'threeMonthEarnRate': 3.4555,
#     'quant': 225,
#     'amonut': 2,
#     'marketSum': 49},
#    {'itemcode': '301410',
#     'etfTabCode': 3,
#     'itemname': 'ARIRANG 코스닥150선물인버스',
#     'nowVal': 6920,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 1.32,
#     'nav': 6912.0,
#     'threeMonthEarnRate': -2.2191,
#     'quant': 19239,
#     'amonut': 132,
#     'marketSum': 48},
#    {'itemcode': '309210',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KRX300헬스케어',
#     'nowVal': 13175,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -0.94,
#     'nav': 13251.0,
#     'threeMonthEarnRate': -3.693,
#     'quant': 1338,
#     'amonut': 17,
#     'marketSum': 47},
#    {'itemcode': '299070',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국채선물10년인버스',
#     'nowVal': 94010,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 93839.0,
#     'threeMonthEarnRate': -1.9555,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 47},
#    {'itemcode': '287300',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200건설',
#     'nowVal': 13665,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.59,
#     'nav': 13668.0,
#     'threeMonthEarnRate': 3.253,
#     'quant': 4471,
#     'amonut': 60,
#     'marketSum': 46},
#    {'itemcode': '275750',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150선물인버스',
#     'nowVal': 4610,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 1.43,
#     'nav': 4607.0,
#     'threeMonthEarnRate': -2.6767,
#     'quant': 11366,
#     'amonut': 52,
#     'marketSum': 46},
#    {'itemcode': '296710',
#     'etfTabCode': 2,
#     'itemname': 'KODEX FnKorea50',
#     'nowVal': 11290,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.4,
#     'nav': 11338.0,
#     'threeMonthEarnRate': -0.1586,
#     'quant': 32,
#     'amonut': 0,
#     'marketSum': 45},
#    {'itemcode': '291660',
#     'etfTabCode': 4,
#     'itemname': 'KODEX China H선물인버스(H)',
#     'nowVal': 11220,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.22,
#     'nav': None,
#     'threeMonthEarnRate': 17.9662,
#     'quant': 20768,
#     'amonut': 234,
#     'marketSum': 45},
#    {'itemcode': '280940',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 골드선물인버스(H)',
#     'nowVal': 7235,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.41,
#     'nav': None,
#     'threeMonthEarnRate': -1.4247,
#     'quant': 1993,
#     'amonut': 14,
#     'marketSum': 43},
#    {'itemcode': '291620',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 코스닥150선물인버스',
#     'nowVal': 7940,
#     'risefall': '2',
#     'changeVal': 110,
#     'changeRate': 1.4,
#     'nav': 7928.0,
#     'threeMonthEarnRate': -2.2472,
#     'quant': 3655,
#     'amonut': 28,
#     'marketSum': 42},
#    {'itemcode': '227560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 생활소비재',
#     'nowVal': 11650,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.13,
#     'nav': 11659.0,
#     'threeMonthEarnRate': -1.1974,
#     'quant': 3865,
#     'amonut': 44,
#     'marketSum': 42},
#    {'itemcode': '267490',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물레버리지(합성 H)',
#     'nowVal': 13900,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': None,
#     'threeMonthEarnRate': 14.876,
#     'quant': 125,
#     'amonut': 1,
#     'marketSum': 42},
#    {'itemcode': '217770',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 원유선물인버스(H)',
#     'nowVal': 5850,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.17,
#     'nav': None,
#     'threeMonthEarnRate': -16.6905,
#     'quant': 2653,
#     'amonut': 15,
#     'marketSum': 41},
#    {'itemcode': '333980',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KS퀄리티가중TR',
#     'nowVal': 16325,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.06,
#     'nav': 16321.0,
#     'threeMonthEarnRate': 1.0829,
#     'quant': 36,
#     'amonut': 0,
#     'marketSum': 41},
#    {'itemcode': '371870',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 차이나항셍테크',
#     'nowVal': 8160,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.87,
#     'nav': None,
#     'threeMonthEarnRate': -22.7317,
#     'quant': 99277,
#     'amonut': 804,
#     'marketSum': 41},
#    {'itemcode': '253240',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 200선물인버스',
#     'nowVal': 4870,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.31,
#     'nav': 4867.0,
#     'threeMonthEarnRate': 0.2051,
#     'quant': 11489,
#     'amonut': 55,
#     'marketSum': 40},
#    {'itemcode': '140580',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 우량업종',
#     'nowVal': 13265,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.08,
#     'nav': 13253.0,
#     'threeMonthEarnRate': 4.37,
#     'quant': 32,
#     'amonut': 0,
#     'marketSum': 40},
#    {'itemcode': '295020',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물10년인버스',
#     'nowVal': 46850,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.11,
#     'nav': 46825.0,
#     'threeMonthEarnRate': -2.0468,
#     'quant': 5,
#     'amonut': 0,
#     'marketSum': 39},
#    {'itemcode': '267450',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#     'nowVal': 7845,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.51,
#     'nav': None,
#     'threeMonthEarnRate': -5.2284,
#     'quant': 2232,
#     'amonut': 17,
#     'marketSum': 39},
#    {'itemcode': '284980',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200금융',
#     'nowVal': 8935,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.96,
#     'nav': 8973.0,
#     'threeMonthEarnRate': -1.6339,
#     'quant': 4356,
#     'amonut': 38,
#     'marketSum': 32},
#    {'itemcode': '211260',
#     'etfTabCode': 2,
#     'itemname': 'KINDEX 배당성장',
#     'nowVal': 39850,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.23,
#     'nav': 39911.0,
#     'threeMonthEarnRate': 0.7466,
#     'quant': 228,
#     'amonut': 9,
#     'marketSum': 32},
#    {'itemcode': '252720',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 모멘텀밸류',
#     'nowVal': 15420,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.46,
#     'nav': 15422.0,
#     'threeMonthEarnRate': -1.9921,
#     'quant': 20,
#     'amonut': 0,
#     'marketSum': 31},
#    {'itemcode': '284990',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200에너지화학',
#     'nowVal': 13995,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.14,
#     'nav': 14035.0,
#     'threeMonthEarnRate': -3.571,
#     'quant': 855,
#     'amonut': 11,
#     'marketSum': 31},
#    {'itemcode': '291890',
#     'etfTabCode': 4,
#     'itemname': 'KODEX MSCI EM선물(H)',
#     'nowVal': 10060,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.54,
#     'nav': None,
#     'threeMonthEarnRate': -7.2444,
#     'quant': 234,
#     'amonut': 2,
#     'marketSum': 30},
#    {'itemcode': '295000',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물10년',
#     'nowVal': 56415,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.11,
#     'nav': 56413.0,
#     'threeMonthEarnRate': 2.0646,
#     'quant': 57,
#     'amonut': 3,
#     'marketSum': 29},
#    {'itemcode': '285020',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200철강소재',
#     'nowVal': 10180,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.05,
#     'nav': 10204.0,
#     'threeMonthEarnRate': -3.0953,
#     'quant': 1658,
#     'amonut': 16,
#     'marketSum': 29},
#    {'itemcode': '267500',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#     'nowVal': 5790,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -1.03,
#     'nav': None,
#     'threeMonthEarnRate': -11.8976,
#     'quant': 6161,
#     'amonut': 35,
#     'marketSum': 26},
#    {'itemcode': '287330',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200생활소비재',
#     'nowVal': 8880,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.34,
#     'nav': 8890.0,
#     'threeMonthEarnRate': -1.7213,
#     'quant': 2235,
#     'amonut': 19,
#     'marketSum': 21},
#    {'itemcode': '334700',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#     'nowVal': 4545,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 1.68,
#     'nav': None,
#     'threeMonthEarnRate': 5.1764,
#     'quant': 1855,
#     'amonut': 8,
#     'marketSum': 18},
#    {'itemcode': '287310',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200경기소비재',
#     'nowVal': 11835,
#     'risefall': '5',
#     'changeVal': -80,
#     'changeRate': -0.67,
#     'nav': 11871.0,
#     'threeMonthEarnRate': 3.1691,
#     'quant': 323,
#     'amonut': 3,
#     'marketSum': 17},
#    {'itemcode': '287320',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200산업재',
#     'nowVal': 13370,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.22,
#     'nav': 13371.0,
#     'threeMonthEarnRate': 9.1653,
#     'quant': 3382,
#     'amonut': 45,
#     'marketSum': 16}]}}

# %% [markdown]
# ### JSON 타입으로 데이터 받기

# %%
# requests 의 응답을 json 타입으로 받습니다.
# etf_json
etf_json = response.json()

# %% [markdown]
# ### JSON 에서 원하는 데이터 찾기

# %%
# result > etfItemList 의 하위 구조로 목록을 찾고자 하는 데이터를 가져옵니다.
# etfItemList
etfitemlist = etf_json['result']['etfItemList']
etfitemlist[0]
# Out:
# {'itemcode': '069500',
#  'etfTabCode': 1,
#  'itemname': 'KODEX 200',
#  'nowVal': 43005,
#  'risefall': '2',
#  'changeVal': 130,
#  'changeRate': 0.3,
#  'nav': 43027.0,
#  'threeMonthEarnRate': -0.7363,
#  'quant': 2409683,
#  'amonut': 103245,
#  'marketSum': 41672}

# %% [markdown]
# ## 데이터프레임 변환
# ### JSON 데이터를 pandas 의 데이터프레임 형태로 만들기

# %%
# 키-값 형태의 데이터를 데이터프레임으로 만듭니다.
# df
df = pd.DataFrame(etfitemlist)
df
# Out:
#     itemcode  etfTabCode                    itemname  nowVal risefall  \
# 0     069500           1                   KODEX 200   43005        2
# 1     153130           6                  KODEX 단기채권  102845        3
# 2     252670           3            KODEX 200선물인버스2X    1930        5
# 3     102110           1                   TIGER 200   43020        2
# 4     102780           2                  KODEX 삼성그룹   10570        2
# ..       ...         ...                         ...     ...      ...
# 484   267500           4  KBSTAR 미국장기국채선물인버스2X(합성 H)    5790        5
# 485   287330           2             KBSTAR 200생활소비재    8880        2
# 486   334700           5          KBSTAR 팔라듐선물인버스(H)    4545        2
# 487   287310           2             KBSTAR 200경기소비재   11835        5
# 488   287320           2               KBSTAR 200산업재   13370        2
#
#      changeVal  changeRate       nav  threeMonthEarnRate      quant  amonut  \
# 0          130        0.30   43027.0             -0.7363    2409683  103245
# 1            0        0.00  102846.0              0.0340      16993    1747
# 2          -10       -0.52    1930.0              0.0000  208297922  404216
# 3           85        0.20   43060.0             -0.7054     917304   39354
# 4           35        0.33   10594.0              3.2033     254361    2680
# ..         ...         ...       ...                 ...        ...     ...
# 484        -60       -1.03       NaN            -11.8976       6161      35
# 485         30        0.34    8890.0             -1.7213       2235      19
# 486         75        1.68       NaN              5.1764       1855       8
# 487        -80       -0.67   11871.0              3.1691        323       3
# 488         30        0.22   13371.0              9.1653       3382      45
#
#      marketSum
# 0        41672
# 1        24206
# 2        22070
# 3        21575
# 4        18180
# ..         ...
# 484         26
# 485         21
# 486         18
# 487         17
# 488         16
#
# [489 rows x 12 columns]

# %% [markdown]
# ### 데이터 확인

# %%
# 데이터 프레임으로 잘 만들어 졌는지 상단 데이터의 일부만 미리보기 합니다.
df.head()
# Out:
#   itemcode  etfTabCode          itemname  nowVal risefall  changeVal  \
# 0   069500           1         KODEX 200   43005        2        130
# 1   153130           6        KODEX 단기채권  102845        3          0
# 2   252670           3  KODEX 200선물인버스2X    1930        5        -10
# 3   102110           1         TIGER 200   43020        2         85
# 4   102780           2        KODEX 삼성그룹   10570        2         35
#
#    changeRate       nav  threeMonthEarnRate      quant  amonut  marketSum
# 0        0.30   43027.0             -0.7363    2409683  103245      41672
# 1        0.00  102846.0              0.0340      16993    1747      24206
# 2       -0.52    1930.0              0.0000  208297922  404216      22070
# 3        0.20   43060.0             -0.7054     917304   39354      21575
# 4        0.33   10594.0              3.2033     254361    2680      18180

# %%
# 데이터 프레임으로 잘 만들어 졌는지 하단 데이터의 일부만 미리보기 합니다.
df.tail()
# Out:
#     itemcode  etfTabCode                    itemname  nowVal risefall  \
# 484   267500           4  KBSTAR 미국장기국채선물인버스2X(합성 H)    5790        5
# 485   287330           2             KBSTAR 200생활소비재    8880        2
# 486   334700           5          KBSTAR 팔라듐선물인버스(H)    4545        2
# 487   287310           2             KBSTAR 200경기소비재   11835        5
# 488   287320           2               KBSTAR 200산업재   13370        2
#
#      changeVal  changeRate      nav  threeMonthEarnRate  quant  amonut  \
# 484        -60       -1.03      NaN            -11.8976   6161      35
# 485         30        0.34   8890.0             -1.7213   2235      19
# 486         75        1.68      NaN              5.1764   1855       8
# 487        -80       -0.67  11871.0              3.1691    323       3
# 488         30        0.22  13371.0              9.1653   3382      45
#
#      marketSum
# 484         26
# 485         21
# 486         18
# 487         17
# 488         16

# %% [markdown]
# ## 파일 저장
# ### 파일명 만들기

# %%
# 파이썬 표준라이브러리인 datetime을 불러옵니다.
# 날짜를 만들어 저장하기 위해 오늘 날짜를 구합니다.
import datetime
today = datetime.datetime.today().strftime('%y-%m-%d')

# %%
# f-string 방식으로 파일명을 만들어 줍니다.
# eft_날짜_raw.csv 형태로 만듭니다.
# file_name
file_name = f"etf_{today}_row.csv"
file_name
# Out:
# 'etf_21-07-28_row.csv'

# %% [markdown]
# ### 파일로 저장하고 불러오기

# %%
# csv 형태로 저장합니다. index 가 저장되지 않도록 합니다.
df.to_csv(file_name, index=False)

# %%
# 저장된 csv 파일을 읽어옵니다.
# itemcode 숫자 앞의 0 이 지워진다면 dtype={"itemcode": np.object} 로 타입을 지정해 주면 문자형태로 읽어옵니다.
pd.read_csv(file_name, dtype={'itemcode':np.object})
# Out:
#     itemcode  etfTabCode                    itemname  nowVal  risefall  \
# 0     069500           1                   KODEX 200   43005         2
# 1     153130           6                  KODEX 단기채권  102845         3
# 2     252670           3            KODEX 200선물인버스2X    1930         5
# 3     102110           1                   TIGER 200   43020         2
# 4     102780           2                  KODEX 삼성그룹   10570         2
# ..       ...         ...                         ...     ...       ...
# 484   267500           4  KBSTAR 미국장기국채선물인버스2X(합성 H)    5790         5
# 485   287330           2             KBSTAR 200생활소비재    8880         2
# 486   334700           5          KBSTAR 팔라듐선물인버스(H)    4545         2
# 487   287310           2             KBSTAR 200경기소비재   11835         5
# 488   287320           2               KBSTAR 200산업재   13370         2
#
#      changeVal  changeRate       nav  threeMonthEarnRate      quant  amonut  \
# 0          130        0.30   43027.0             -0.7363    2409683  103245
# 1            0        0.00  102846.0              0.0340      16993    1747
# 2          -10       -0.52    1930.0              0.0000  208297922  404216
# 3           85        0.20   43060.0             -0.7054     917304   39354
# 4           35        0.33   10594.0              3.2033     254361    2680
# ..         ...         ...       ...                 ...        ...     ...
# 484        -60       -1.03       NaN            -11.8976       6161      35
# 485         30        0.34    8890.0             -1.7213       2235      19
# 486         75        1.68       NaN              5.1764       1855       8
# 487        -80       -0.67   11871.0              3.1691        323       3
# 488         30        0.22   13371.0              9.1653       3382      45
#
#      marketSum
# 0        41672
# 1        24206
# 2        22070
# 3        21575
# 4        18180
# ..         ...
# 484         26
# 485         21
# 486         18
# 487         17
# 488         16
#
# [489 rows x 12 columns]
