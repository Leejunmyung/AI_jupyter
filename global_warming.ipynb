# %%
import numpy as np
import pandas as pd
import os

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
all = pd.read_csv('gt.csv', encoding='cp949')
all
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1855-05-01              25.544                          1.171
# 1       1855-06-01              24.228                          1.103
# 2       1855-07-01              24.371                          1.044
# 3       1855-08-01              25.427                          1.073
# 4       1855-09-01              25.675                          1.014
# ...            ...                 ...                            ...
# 645670  2013-05-01              21.634                          0.578
# 645671  2013-06-01              24.679                          0.596
# 645672  2013-07-01              29.272                          1.340
# 645673  2013-08-01              29.202                          0.869
# 645674  2013-09-01                 NaN                            NaN
#
#            State Country
# 0           Acre  Brazil
# 1           Acre  Brazil
# 2           Acre  Brazil
# ...

# %%
shot = all.tail(100)

# %%
sns.histplot(x="AverageTemperature",hue="State", data=all)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-988462abb871> in <module>
# ----> 1 sns.histplot(x="AverageTemperature",hue="State", data=all)
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="Country", y="AverageTemperature", data=all)
plt.show()

# %%
fgpivot = shot.pivot("dt","AverageTemperature","Country")
fgpivot
# Out:
# AverageTemperature NaN    2.020  4.532  4.697  4.733  4.910  5.120  5.523   \
# dt
# 2005-06-01            NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2005-07-01            NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2005-08-01            NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2005-09-01            NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2005-10-01            NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...                   ...    ...    ...    ...    ...    ...    ...    ...
# 2013-05-01            NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-06-01            NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-07-01            NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-08-01            NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-09-01          China    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(x="dt", y="AverageTemperature", hue="State", data=shot)

# %%
sns.lmplot(x="dt", y="AverageTemperature", hue="Country", data=shot, size=7)
# Out:
# C:\Users\wnsau\anaconda3\lib\site-packages\seaborn\regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-19-a8a99c1e1f29> in <module>
# ----> 1 sns.lmplot(x="dt", y="AverageTemperature", hue="Country", data=shot, size=7)
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     614         scatter_kws=scatter_kws, line_kws=line_kws,
#     615         )
# ...

# %%
df = pd.read_csv(
                "gt.csv",
                usecols=['Country','dt','AverageTemperature'],
                parse_dates=['dt'])
countries = ['United States', 'India', 'China', 'Russia','Brazil']
df = df[df['Country'].isin(countries)]
df = df[df['dt'] > '2000-01-01']
print(df)
import matplotlib as mpl
from matplotlib import pyplot as plt
data = df.pivot('dt', 'Country', 'AverageTemperature')
data=data.fillna(0)
print(data)
data.plot()
# Out:
#                dt  AverageTemperature Country
# 1737   2000-02-01              26.102  Brazil
# 1738   2000-03-01              26.107  Brazil
# 1739   2000-04-01              25.952  Brazil
# 1740   2000-05-01              25.832  Brazil
# 1741   2000-06-01              25.032  Brazil
# ...           ...                 ...     ...
# 645670 2013-05-01              21.634   China
# 645671 2013-06-01              24.679   China
# 645672 2013-07-01              29.272   China
# 645673 2013-08-01              29.202   China
# 645674 2013-09-01                 NaN   China
#
# [36244 rows x 3 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-cc9a2f03f1ae> in <module>
#       9 import matplotlib as mpl
#      10 from matplotlib import pyplot as plt
# ---> 11 data = df.pivot('dt', 'Country', 'AverageTemperature')
#      12 data=data.fillna(0)
# ...
