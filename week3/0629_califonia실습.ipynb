# %%
import pandas as pd
test = pd.read_csv("california_housing_test.csv")
train = pd.read_csv("california_housing_train.csv")

# %%
test.shape, train.shape
# Out:
# ((3000, 9), (17000, 9))

# %%
test.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
train.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
train.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
train.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        17000.000000
# mean        207300.912353
# std         115983.764387
# min          14999.000000
# 25%         119400.000000
# 50%         180400.000000
# 75%         265000.000000
# max         500001.000000

# %%
test.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
train.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
train.hist(figsize=(20,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002429167F730>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000242928106A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002429283CB20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024292869F70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000242928A2400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000242928D14C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000242928D15B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000242928FBD60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024292958C10>]],
#       dtype=object)

# %%
train.plot(kind='scatter', x='longitude', y='latitude',
           alpha=0.4, s=train['population']/100, label='population',
           c='median_house_value',figsize=(12,8), cmap=plt.get_cmap("jet"),
           colorbar=True)

# %%
train.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
sel = ['total_rooms', 'total_bedrooms', 'population']
temp_train = train[ sel ]
print("데이터 가공 셋의 크기 : ", temp_train.shape)
print("데이터 가공 셋의 일부 : ", temp_train.head())
# Out:
# 데이터 가공 셋의 크기 :  (17000, 3)
# 데이터 가공 셋의 일부 :     total_rooms  total_bedrooms  population
# 0       5612.0          1283.0      1015.0
# 1       7650.0          1901.0      1129.0
# 2        720.0           174.0       333.0
# 3       1501.0           337.0       515.0
# 4       1454.0           326.0       624.0

# %%
temp_train.describe()
# Out:
#         total_rooms  total_bedrooms    population
# count  17000.000000    17000.000000  17000.000000
# mean    2643.664412      539.410824   1429.573941
# std     2179.947071      421.499452   1147.852959
# min        2.000000        1.000000      3.000000
# 25%     1462.000000      297.000000    790.000000
# 50%     2127.000000      434.000000   1167.000000
# 75%     3151.250000      648.250000   1721.000000
# max    37937.000000     6445.000000  35682.000000

# %% [markdown]
# ### 실습) 방이 37937이 어디에 위치하고 있는지 위도, 경도 값을 확보해보기

# %%
max_room_info = train.loc[train['total_rooms']==37937, :]
max_room_info
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2871    -117.74     33.89                 4.0      37937.0          5471.0
#
#       population  households  median_income  median_house_value
# 2871     16122.0      5189.0         7.4947            366300.0

# %%
import seaborn as sns

# %%
fig = plt.figure(figsize=(12,8))

plt.subplot(3,1,1)
sns.boxplot(x='total_rooms', data=temp_train)

plt.subplot(3,1,2)
sns.boxplot(x='total_bedrooms', data=temp_train)

plt.subplot(3,1,3)
sns.boxplot(x='population', data=temp_train)

# %%
sns.pairplot(temp_train)

# %%
temp_train.corr()
# Out:
#                 total_rooms  total_bedrooms  population
# total_rooms        1.000000        0.928403    0.860170
# total_bedrooms     0.928403        1.000000    0.881169
# population         0.860170        0.881169    1.000000

# %%
plt.figure(figsize=(10,10))
plt.subplot(3,3,1) 
sns.boxplot(x="total_rooms", data=train)
plt.subplot(3,3,2) 
sns.boxplot(x="total_bedrooms", data=train)
plt.subplot(3,3,3) 
sns.boxplot(x="population", data=train)  
plt.subplot(3,3,4) 
sns.boxplot(x="longitude", data=train)
plt.subplot(3,3,5) 
sns.boxplot(x="latitude", data=train)
plt.subplot(3,3,6) 
sns.boxplot(x="households", data=train)  
plt.subplot(3,3,7) 
sns.boxplot(x="median_income", data=train)
plt.subplot(3,3,8) 
sns.boxplot(x="median_house_value", data=train)

# %%
all = [0,'total_rooms','total_bedrooms','population',
       'longitude','latitude','households','median_income','median_house_value']
plt.figure(figsize=(10,10))
for i in range(1,len(all)):
    plt.subplot(3,3,i)
    sns.boxplot(x=all[i], data=train)

# %%
all[1]
# Out:
# 'total_bedrooms'

# %%
len(all)
# Out:
# 8

# %%
plt.figure(figsize=(12,8))
for i in range(1,10):
    plt.subplot(3,3,i)
    sns.boxplot(x=train.columns[i-1], data=train)

# %%
## 두 컬럼 선택 
temp02 = train.loc[:,  [ "median_income", "median_house_value" ] ]
temp02.head()
# Out:
#    median_income  median_house_value
# 0         1.4936             66900.0
# 1         1.8200             80100.0
# 2         1.6509             85700.0
# 3         3.1917             73400.0
# 4         1.9250             65500.0

# %%
## 두 컬럼 선택 8열, 9열
temp03 = train.iloc[:,  [7, 8] ]
print( temp03.head() )
temp03 = train.iloc[:,  [-2, -1] ]
print( temp03.head() )
# Out:
#    median_income  median_house_value
# 0         1.4936             66900.0
# 1         1.8200             80100.0
# 2         1.6509             85700.0
# 3         3.1917             73400.0
# 4         1.9250             65500.0
#    median_income  median_house_value
# 0         1.4936             66900.0
# 1         1.8200             80100.0
# 2         1.6509             85700.0
# 3         3.1917             73400.0
# 4         1.9250             65500.0

# %%
train.total_rooms.describe()
# Out:
# count    17000.000000
# mean      2643.664412
# std       2179.947071
# min          2.000000
# 25%       1462.000000
# 50%       2127.000000
# 75%       3151.250000
# max      37937.000000
# Name: total_rooms, dtype: float64

# %%
tmp_A1 = train.loc[train['total_rooms'] >= 3151, :]
tmp_A2 = train.loc[(train['total_rooms'] >= 2127) & (train['total_rooms'] < 3151), :]
tmp_A3 = train.loc[(train['total_rooms'] >= 1462) & (train['total_rooms'] < 2127), :]
tmp_A4 = train.loc[train['total_rooms'] < 1462, :]

tmp_A1.shape, tmp_A2.shape, tmp_A3.shape, tmp_A4.shape
# Out:
# ((4251, 9), (4246, 9), (4238, 9), (4245, 9))

# %%
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %%
tmp_A1 = train.loc[train['total_rooms'] >= 3151, 'room_level'] = 1
tmp_A2 = train.loc[(train['total_rooms'] > 2127) & (train['total_rooms'] < 3151), 'room_level'] = 2
tmp_A3 = train.loc[(train['total_rooms'] > 1462) & (train['total_rooms'] < 2127), 'room_level'] = 3
tmp_A4 = train.loc[train['total_rooms'] < 1462, 'room_level'] = 4

# %%
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  room_level
# 0          1015.0       472.0         1.4936             66900.0         1.0
# 1          1129.0       463.0         1.8200             80100.0         1.0
# 2           333.0       117.0         1.6509             85700.0         4.0
# 3           515.0       226.0         3.1917             73400.0         3.0
# 4           624.0       262.0         1.9250             65500.0         4.0
# ...           ...         ...            ...                 ...         ...
# 16995       907.0       369.0         2.3571            111400.0         2.0
# 16996      1194.0       465.0         2.5179             79000.0         2.0
# 16997      1244.0       456.0         3.0313            103600.0         2.0
# 16998      1298.0       478.0         1.9797             85800.0         2.0
# 16999       806.0       270.0         3.0147             94600.0         3.0
#
# [17000 rows x 10 columns]

# %%
test.total_rooms.describe()
# Out:
# count     3000.000000
# mean      2599.578667
# std       2155.593332
# min          6.000000
# 25%       1401.000000
# 50%       2106.000000
# 75%       3129.000000
# max      30450.000000
# Name: total_rooms, dtype: float64

# %%
tmp_B1 = test.loc[train['total_rooms'] >= 3129, :]
tmp_B2 = test.loc[(train['total_rooms'] >= 2106) & (train['total_rooms'] < 3129), :]
tmp_B3 = test.loc[(train['total_rooms'] >= 1401) & (train['total_rooms'] < 2106), :]
tmp_B4 = test.loc[train['total_rooms'] < 1401, :]

tmp_B1.shape, tmp_B2.shape, tmp_B3.shape, tmp_B4.shape
# Out:
# ((1051, 9), (754, 9), (641, 9), (554, 9))

# %%
tmp_B1 = test.loc[train['total_rooms'] >= 3129, 'room_level'] = 1
tmp_B2 = test.loc[(train['total_rooms'] >= 2106) & (train['total_rooms'] < 3129), 'room_level'] = 2
tmp_B3 = test.loc[(train['total_rooms'] >= 1401) & (train['total_rooms'] < 2106), 'room_level'] = 3
tmp_B4 = test.loc[train['total_rooms'] < 1401, 'room_level'] = 4

test
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value  room_level
# 0         1537.0       606.0         6.6085            344700.0         1.0
# 1          809.0       277.0         3.5990            176500.0         1.0
# 2         1484.0       495.0         5.7934            270500.0         4.0
# 3           49.0        11.0         6.1359            330000.0         3.0
# 4          850.0       237.0         2.9375             81700.0         3.0
# ...          ...         ...            ...                 ...         ...
# 2995      1258.0       607.0         1.1790            225000.0         1.0
# 2996      3496.0      1036.0         3.3906            237200.0         1.0
# 2997       693.0       220.0         2.2895             62000.0         1.0
# 2998        46.0        14.0         3.2708            162500.0         1.0
# 2999       753.0       260.0         8.5608            500001.0         1.0
#
# [3000 rows x 10 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
#  9   room_level          16980 non-null  float64
# dtypes: float64(10)
# memory usage: 1.3 MB

# %%
train['room_level'] = train.room_level.astype('category')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
#  9   room_level          16980 non-null  category
# dtypes: category(1), float64(9)
# memory usage: 1.2 MB

# %%
sns.boxplot(x='room_level', y='housing_median_age', data=train)

# %%
sns.barplot(x='room_level', y='housing_median_age', data=train)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
#  9   room_level          16980 non-null  category
# dtypes: category(1), float64(9)
# memory usage: 1.2 MB

# %%
sns.barplot(x='room_level', y='population', data=train)
